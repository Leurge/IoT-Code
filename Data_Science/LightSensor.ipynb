# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.plot(light_sensor.sensorReading, light_sensor.timestamp)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#%%

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#%%

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#%%

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#%%

# %%
#%%

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
#%%

# %%
#%%

# %%
#%%

# %%
#%%

# %%
#%%

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
x = np.array([datetime.datetime(2019, 2, 14, i, 0) for i in range(24)])
y = light_sensor.sensorReadings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-160-f82c447f0466> in <module>
#       1 #%%
# ----> 2 x = np.array([datetime.datetime(2019, 2, 14, i, 0) for i in range(24)])
#       3 y = light_sensor.sensorReadings
#
# <ipython-input-160-f82c447f0466> in <listcomp>(.0)
#       1 #%%
# ----> 2 x = np.array([datetime.datetime(2019, 2, 14, i, 0) for i in range(24)])
#       3 y = light_sensor.sensorReadings
#
# NameError: name 'datetime' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
x = np.array([datetime.datetime(2019, 2, 14, i, 0) for i in range(24)])
y = light_sensor.sensorReadings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-f82c447f0466> in <module>
#       1 #%%
# ----> 2 x = np.array([datetime.datetime(2019, 2, 14, i, 0) for i in range(24)])
#       3 y = light_sensor.sensorReadings
#
# <ipython-input-164-f82c447f0466> in <listcomp>(.0)
#       1 #%%
# ----> 2 x = np.array([datetime.datetime(2019, 2, 14, i, 0) for i in range(24)])
#       3 y = light_sensor.sensorReadings
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
plt.plot(dates,values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-166-89a0926aaff2> in <module>
#       1 #%%
# ----> 2 plt.plot(dates,values)
#
# NameError: name 'dates' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
x = light_sensor.timestamp
y = light_sensor.sensorReadings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-170-5ba63821e55e> in <module>
#       1 #%%
#       2 x = light_sensor.timestamp
# ----> 3 y = light_sensor.sensorReadings
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sensorReadings'

# %%
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-d6205e1c5e93> in <module>
#       1 #%%
# ----> 2 plt.plot(x, y)
#       3 plt.show()
#
# NameError: name 'y' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
x = light_sensor.timestamp
y = light_sensor.sensorReadings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-175-5ba63821e55e> in <module>
#       1 #%%
#       2 x = light_sensor.timestamp
# ----> 3 y = light_sensor.sensorReadings
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sensorReadings'

# %%
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-176-d6205e1c5e93> in <module>
#       1 #%%
# ----> 2 plt.plot(x, y)
#       3 plt.show()
#
# NameError: name 'y' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime

# %%
light_sensor = pd.read_csv("/home/wenzel/projects/W.csv")

# %%
light_sensor
# Out:
#                            _id  __v deviceId sensorId  sensorReading  \
# 0     5c65f907e0b12e539fdca0c3    0        W        l              9
# 1     5c65f909e0b12e539fdca0c7    0        W        l            922
# 2     5c65f90be0b12e539fdca0c9    0        W        l            921
# 3     5c65f90de0b12e539fdca0cb    0        W        l            948
# 4     5c65f90fe0b12e539fdca0cd    0        W        l            947
# 5     5c65f919e0b12e539fdca0d5    0        W        l            948
# 6     5c65f91be0b12e539fdca0db    0        W        l            948
# 7     5c65f91de0b12e539fdca0dd    0        W        l            948
# 8     5c65f91fe0b12e539fdca0df    0        W        l            948
# 9     5c65f921e0b12e539fdca0e1    0        W        l            948
# 10    5c65f923e0b12e539fdca0e3    0        W        l            948
# 11    5c65f925e0b12e539fdca0e5    0        W        l            948
# 12    5c65f927e0b12e539fdca0e7    0        W        l            948
# ...

# %%
x = light_sensor.timestamp
y = light_sensor.sensorReading

# %%
plt.plot(x, y)
plt.show()
